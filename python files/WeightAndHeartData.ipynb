# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Heart Data

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Week8_datasets/heartrate_seconds_merged.csv')

# %%
df.head()
# Out:
#            Id                  Time  Value
# 0  2022484408  4/12/2016 7:21:00 AM     97
# 1  2022484408  4/12/2016 7:21:05 AM    102
# 2  2022484408  4/12/2016 7:21:10 AM    105
# 3  2022484408  4/12/2016 7:21:20 AM    103
# 4  2022484408  4/12/2016 7:21:25 AM    101

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2483658 entries, 0 to 2483657
# Data columns (total 3 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   Id      int64
#  1   Time    object
#  2   Value   int64
# dtypes: int64(2), object(1)
# memory usage: 56.8+ MB

# %%
df['Time'] = pd.to_datetime(df['Time'])

# %%
#Checking for null values
df.isnull().sum()
# Out:
# Id       0
# Time     0
# Value    0
# dtype: int64

# %%
df.shape
# Out:
# (2483658, 3)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#            Id                Time  Value
# 0  2022484408 2016-04-12 07:21:00     97
# 1  2022484408 2016-04-12 07:21:05    102
# 2  2022484408 2016-04-12 07:21:10    105
# 3  2022484408 2016-04-12 07:21:20    103
# 4  2022484408 2016-04-12 07:21:25    101

# %%
df['Time'] = pd.to_datetime(df['Time']).dt.strftime('%Y-%m-%d %I:%M %p')
df['Time'] = df['Time'].str.replace('-', '/')

# %%
df.head()
# Out:
#            Id                 Time  Value
# 0  2022484408  2016/04/12 07:21 AM     97
# 1  2022484408  2016/04/12 07:21 AM    102
# 2  2022484408  2016/04/12 07:21 AM    105
# 3  2022484408  2016/04/12 07:21 AM    103
# 4  2022484408  2016/04/12 07:21 AM    101

# %% [markdown]
# # Weight data

# %%
weight_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Week8_datasets/weightLogInfo_merged.csv')
weight_df.head()
# Out:
#            Id                   Date    WeightKg  WeightPounds   Fat  \
# 0  1503960366   5/2/2016 11:59:59 PM   52.599998    115.963147  22.0
# 1  1503960366   5/3/2016 11:59:59 PM   52.599998    115.963147   NaN
# 2  1927972279   4/13/2016 1:08:52 AM  133.500000    294.317120   NaN
# 3  2873212765  4/21/2016 11:59:59 PM   56.700001    125.002104   NaN
# 4  2873212765  5/12/2016 11:59:59 PM   57.299999    126.324875   NaN
#
#          BMI  IsManualReport          LogId
# 0  22.650000            True  1462233599000
# 1  22.650000            True  1462319999000
# 2  47.540001           False  1460509732000
# 3  21.450001            True  1461283199000
# 4  21.690001            True  1463097599000

# %%
weight_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              67 non-null     int64
#  1   Date            67 non-null     object
#  2   WeightKg        67 non-null     float64
#  3   WeightPounds    67 non-null     float64
#  4   Fat             2 non-null      float64
#  5   BMI             67 non-null     float64
#  6   IsManualReport  67 non-null     bool
#  7   LogId           67 non-null     int64
# dtypes: bool(1), float64(4), int64(2), object(1)
# memory usage: 3.9+ KB

# %%
weight_df.isnull().sum()
# Out:
# Id                 0
# Date               0
# WeightKg           0
# WeightPounds       0
# Fat               65
# BMI                0
# IsManualReport     0
# LogId              0
# dtype: int64

# %%
weight_df.duplicated().sum()
# Out:
# 0

# %%
weight_df.drop_duplicates(inplace=True)

# %%
weight_df.shape
# Out:
# (67, 8)

# %%
weight_df['Date'] = pd.to_datetime(weight_df['Date']).dt.strftime('%Y-%m-%d %I:%M %p')
weight_df['Date'] = weight_df['Date'].str.replace('-', '/')
# Out:
# <ipython-input-19-c15f812860ae>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   weight_df['Date'] = pd.to_datetime(weight_df['Date']).dt.strftime('%Y-%m-%d %I:%M %p')

# %%
weight_df.head()
# Out:
#            Id                 Date    WeightKg  WeightPounds   Fat        BMI  \
# 0  1503960366  2016/05/02 11:59 PM   52.599998    115.963147  22.0  22.650000
# 1  1503960366  2016/05/03 11:59 PM   52.599998    115.963147   NaN  22.650000
# 2  1927972279  2016/04/13 01:08 AM  133.500000    294.317120   NaN  47.540001
# 3  2873212765  2016/04/21 11:59 PM   56.700001    125.002104   NaN  21.450001
# 4  2873212765  2016/05/12 11:59 PM   57.299999    126.324875   NaN  21.690001
#
#    IsManualReport          LogId
# 0            True  1462233599000
# 1            True  1462319999000
# 2           False  1460509732000
# 3            True  1461283199000
# 4            True  1463097599000

# %% [markdown]
# # Saving the dataset

# %%
df.to_csv('/content/drive/MyDrive/Colab Notebooks/Week8_datasets/heartrate_seconds_Cleaned.csv', index=False)
weight_df.to_csv('/content/drive/MyDrive/Colab Notebooks/Week8_datasets/weightLogInfo_cleaned.csv', index=False)
